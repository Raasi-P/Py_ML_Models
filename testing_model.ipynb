# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Loading the Dataset

# %%
data = pd.read_excel('Online_Retail_Store.xlsx')
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
data.tail()
# Out:
#        InvoiceNo StockCode  ... CustomerID  Country
# 541904    581587     22613  ...    12680.0   France
# 541905    581587     22899  ...    12680.0   France
# 541906    581587     23254  ...    12680.0   France
# 541907    581587     23255  ...    12680.0   France
# 541908    581587     22138  ...    12680.0   France
#
# [5 rows x 8 columns]

# %%
data.memory_usage()
# Out:
# Index              128
# InvoiceNo      4335272
# StockCode      4335272
# Description    4335272
# Quantity       4335272
# InvoiceDate    4335272
# UnitPrice      4335272
# CustomerID     4335272
# Country        4335272
# dtype: int64

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 4335272

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=541909, step=1)

# %%
data.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]>

# %%
data.isna()
# Out:
#         InvoiceNo  StockCode  Description  ...  UnitPrice  CustomerID  Country
# 0           False      False        False  ...      False       False    False
# 1           False      False        False  ...      False       False    False
# 2           False      False        False  ...      False       False    False
# 3           False      False        False  ...      False       False    False
# 4           False      False        False  ...      False       False    False
# ...           ...        ...          ...  ...        ...         ...      ...
# 541904      False      False        False  ...      False       False    False
# 541905      False      False        False  ...      False       False    False
# 541906      False      False        False  ...      False       False    False
# 541907      False      False        False  ...      False       False    False
# 541908      False      False        False  ...      False       False    False
#
# ...

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# # Data Preparation

# %%
data['Description'] = data['Description'].str.strip()
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')
data = data[~data['InvoiceNo'].str.contains('C')]
data
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [532621 rows x 8 columns]

# %%
data['Country'].value_counts()
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %%
my_store = (data[data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
my_store.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
#
# [5 rows x 1563 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
my_store_sets = my_store.applymap(encode_units)
my_store_sets.drop('POSTAGE', inplace=True, axis=1)
my_store_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
#
# [5 rows x 1562 columns]

# %% [markdown]
# # Training model

# %%
my_frequent_itemsets = apriori(my_store_sets, min_support=0.07, use_colnames=True)
my_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
my_rules.head()
# Out:
#                     antecedents  ... conviction
# 0  (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 1   (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 2  (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 3    (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 4    (ALARM CLOCK BAKELIKE RED)  ...   4.153061
#
# [5 rows x 9 columns]

# %% [markdown]
# # My Recommandations

# %%
my_store_sets['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 37

# %%
my_store_sets['ALARM CLOCK BAKELIKE PINK'].sum()
# Out:
# 40

# %%
my_rules[ (my_rules['lift'] >= 3) &
      (my_rules['confidence'] >= 0.3) ]
my_rules.head()
# Out:
#                     antecedents  ... conviction
# 0  (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 1   (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 2  (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 3    (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 4    (ALARM CLOCK BAKELIKE RED)  ...   4.153061
#
# [5 rows x 9 columns]
